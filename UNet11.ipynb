# %% [markdown]
# <a href="https://colab.research.google.com/github/jsun-dev/capstone-experiment/blob/main/UNet11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# !pip install imutils

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('drive/My Drive')

# %%
# !ls
# Out:
# 'Capstone Backup'  'Colab Notebooks'   dataset

# %%
import cv2
import imutils
from google.colab.patches import cv2_imshow

# %matplotlib inline
# from matplotlib import pyplot as plt

img = cv2.imread('dataset/train/images/alb_id_01.jpg')
# img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2_imshow(imutils.resize(img, height=800))
# Out:
# <PIL.Image.Image image mode=RGB size=450x800 at 0x7F9F9B392A10>
